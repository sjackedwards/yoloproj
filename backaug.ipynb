# %%
from cmath import cos, sin
from math import radians
import cv2
import os
import random
import numpy as np

categories = [
    {"id": 0, "name": "2_of_clubs"},
    {"id": 1, "name": "2_of_diamonds"},
    {"id": 2, "name": "2_of_hearts"},
    {"id": 3, "name": "2_of_spades"},
    {"id": 4, "name": "3_of_clubs"},
    {"id": 5, "name": "3_of_diamonds"},
    {"id": 6, "name": "3_of_hearts"},
    {"id": 7, "name": "3_of_spades"},
    {"id": 8, "name": "4_of_clubs"},
    {"id": 9, "name": "4_of_diamonds"},
    {"id": 10, "name": "4_of_hearts"},
    {"id": 11, "name": "4_of_spades"},
    {"id": 12, "name": "5_of_clubs"},
    {"id": 13, "name": "5_of_diamonds"},
    {"id": 14, "name": "5_of_hearts"},
    {"id": 15, "name": "5_of_spades"},
    {"id": 16, "name": "6_of_clubs"},
    {"id": 17, "name": "6_of_diamonds"},
    {"id": 18, "name": "6_of_hearts"},
    {"id": 19, "name": "6_of_spades"},
    {"id": 20, "name": "7_of_clubs"},
    {"id": 21, "name": "7_of_diamonds"},
    {"id": 22, "name": "7_of_hearts"},
    {"id": 23, "name": "7_of_spades"},
    {"id": 24, "name": "8_of_clubs"},
    {"id": 25, "name": "8_of_diamonds"},
    {"id": 26, "name": "8_of_hearts"},
    {"id": 27, "name": "8_of_spades"},
    {"id": 28, "name": "9_of_clubs"},
    {"id": 29, "name": "9_of_diamonds"},
    {"id": 30, "name": "9_of_hearts"},
    {"id": 31, "name": "9_of_spades"},
    {"id": 32, "name": "10_of_clubs"},
    {"id": 33, "name": "10_of_diamonds"},
    {"id": 34, "name": "10_of_hearts"},
    {"id": 35, "name": "10_of_spades"},
    {"id": 36, "name": "ace_of_clubs"},
    {"id": 37, "name": "ace_of_diamonds"},
    {"id": 38, "name": "ace_of_hearts"},
    {"id": 39, "name": "ace_of_spades"},
    {"id": 40, "name": "ace_of_spades2"},
    {"id": 41, "name": "black_joker"},
    {"id": 42, "name": "jack_of_clubs"},
    {"id": 43, "name": "jack_of_clubs2"},
    {"id": 44, "name": "jack_of_diamonds"},
    {"id": 45, "name": "jack_of_diamonds2"},
    {"id": 46, "name": "jack_of_hearts"},
    {"id": 47, "name": "jack_of_hearts2"},
    {"id": 48, "name": "jack_of_spades"},
    {"id": 49, "name": "jack_of_spades2"},
    {"id": 50, "name": "king_of_clubs"},
    {"id": 51, "name": "king_of_clubs2"},
    {"id": 52, "name": "king_of_diamonds"},
    {"id": 53, "name": "king_of_diamonds2"},
    {"id": 54, "name": "king_of_hearts"},
    {"id": 55, "name": "king_of_hearts2"},
    {"id": 56, "name": "king_of_spades"},
    {"id": 57, "name": "king_of_spades2"},
    {"id": 58, "name": "queen_of_clubs"},
    {"id": 59, "name": "queen_of_clubs2"},
    {"id": 60, "name": "queen_of_diamonds"},
    {"id": 61, "name": "queen_of_diamonds2"},
    {"id": 62, "name": "queen_of_hearts"},
    {"id": 63, "name": "queen_of_hearts2"},
    {"id": 64, "name": "queen_of_spades"},
    {"id": 65, "name": "queen_of_spades2"},
]

label_to_id = {category["name"]: category["id"] for category in categories}

def generate_random_polygon(image, min_area):
    height, width = image.shape[:2]
    points = np.random.randint(0, [width, height], (3, 2))
    while True:
        area = 0.5 * np.abs(np.cross(points[1] - points[0], points[2] - points[0]))
        if area >= min_area:
            return points.reshape((-1, 1, 2))
        points = np.random.randint(0, [width, height], (3, 2))

def adjust_contrast_brightness(image):
    alpha = random.uniform(0.5, 1.5)
    beta = random.randint(-50, 50)
    adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)
    return adjusted_image

def add_triangle(image, num_shadows, min_area, transparency):
    image_with_shadow = np.copy(image)
    
    for _ in range(num_shadows):
        temp_img = np.copy(image)
        polygon = generate_random_polygon(image, min_area)
        shadow_color = (np.random.randint(0, 255), np.random.randint(0, 255), np.random.randint(0, 255))  
        
        cv2.fillPoly(temp_img, [polygon], shadow_color)
        cv2.addWeighted(image_with_shadow, transparency, temp_img, transparency, 0, image_with_shadow)
    
    return image_with_shadow

def shear_image(image, shear_factor=0.0):
    rows, cols, _ = image.shape
    M = np.array([[1, shear_factor, 0], [0, 1, 0]])
    sheared_img = cv2.warpAffine(image, M, (cols, rows))
    
    if shear_factor > 0:
        sheared_img = sheared_img[:, int(cols*shear_factor):]
    elif shear_factor < 0:
        sheared_img = sheared_img[:, :int(cols*(1+shear_factor))]
    
    return sheared_img

def process_image(image, min_area, num_shadows, shear_factor, poly_transparency):
    image = add_triangle(image, num_shadows=num_shadows, min_area=min_area, transparency=poly_transparency)
    image = adjust_contrast_brightness(image)
    image = shear_image(image, shear_factor=shear_factor)
    
    return image

def gen_background():
    backgrounds_dir = "bg_base_imgs"
    backgrounds = os.listdir(backgrounds_dir)
    selected_background_filename = random.choice(backgrounds)
    print(selected_background_filename)
    selected_background_path = os.path.join(backgrounds_dir, selected_background_filename)
    background_img = cv2.imread(selected_background_path)
    processed_image = process_image(background_img, 5000, 7, 0.2, 0.5)

    return processed_image


def fix_canvas(image, img_size):
    canvas_width, canvas_height = img_size
    canvas_size = max(canvas_width, canvas_height, image.shape[1], image.shape[0])
    blank_canvas = np.zeros((canvas_size, canvas_size, 4), dtype=np.uint8)

    x_offset = (canvas_size - image.shape[1]) // 2
    y_offset = (canvas_size - image.shape[0]) // 2

    x_offset = max(0, x_offset)
    y_offset = max(0, y_offset)

    blank_canvas[y_offset:y_offset+image.shape[0], x_offset:x_offset+image.shape[1], :] = image

    return blank_canvas

def rotate_image(image, angle):
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)

    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])

    new_w = int((h * sin) + (w * cos))
    new_h = int((h * cos) + (w * sin))

    M[0, 2] += (new_w / 2) - center[0]
    M[1, 2] += (new_h / 2) - center[1]

    if len(image.shape) == 2:
        rotated_image = cv2.warpAffine(image, M, (new_w, new_h))
    elif image.shape[2] == 4:
        alpha_channel = image[:, :, 3]
        rotated_alpha = cv2.warpAffine(alpha_channel, M, (new_w, new_h))
        rotated_image = cv2.warpAffine(image[:, :, :3], M, (new_w, new_h))
        rotated_image = cv2.merge([rotated_image, rotated_alpha])
    else:
        rotated_image = cv2.warpAffine(image, M, (new_w, new_h))

    return rotated_image

def random_zoom(image, zoom_factor):
    new_w = int(image.shape[1] * zoom_factor)
    new_h = int(image.shape[0] * zoom_factor)
    resized_image = cv2.resize(image, (new_w, new_h), interpolation=cv2.INTER_LINEAR)

    return resized_image

def random_shear(image, shear_factor_x, shear_factor_y):
    (h, w) = image.shape[:2]
    M = np.array([[1, shear_factor_x, 0],
                  [shear_factor_y, 1, 0]], dtype=float)

    sheared_image = cv2.warpAffine(image, M, (w + int(shear_factor_x * h), h + int(shear_factor_y * w)))

    return sheared_image

def random_shadows(image):
    alpha_channel = image[:, :, 3]
    image_rgb = image[:, :, :3]
    shadow_mask = np.zeros(image_rgb.shape[:2], dtype=np.uint8)

    num_shadows = random.randint(3, 9)
    for _ in range(num_shadows):
        x = random.randint(0, image_rgb.shape[1] // 4)
        y = random.randint(0, image_rgb.shape[0] // 4)
        w = random.randint(image_rgb.shape[1] // 4, image_rgb.shape[1] // 2)
        h = random.randint(image_rgb.shape[0] // 4, image_rgb.shape[0] // 2)

        w = min(w, image_rgb.shape[1] - x)
        h = min(h, image_rgb.shape[0] - y)

        intensity = random.randint(30, 180)
        gradient = np.linspace(intensity, 0, max(w, h)).astype(np.uint8)
        shadow = np.zeros((h, w), dtype=np.uint8)
        for i in range(h):
            shadow[i, :] = gradient[:w]

        shadow_mask[y:y+h, x:x+w] = shadow

    shadow_mask_bgr = cv2.cvtColor(shadow_mask, cv2.COLOR_GRAY2BGR)
    shadowed_image_rgb = cv2.addWeighted(image_rgb, 1, shadow_mask_bgr, -0.5, 0)
    shadowed_image = cv2.merge((shadowed_image_rgb, alpha_channel))

    return shadowed_image

def random_noise(image):
    height, width, _ = image.shape
    noise = np.random.normal(0.05, .35, (height, width, 3)).astype(np.uint8)

    noisy_image = image.copy()
    noisy_image[:, :, :3] = np.clip(noisy_image[:, :, :3] + noise, 0, 255).astype(np.uint8)

    return noisy_image

def get_bbox(image):
    alpha_channel = image[:, :, 3]
    _, binary_alpha = cv2.threshold(alpha_channel, 1, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary_alpha, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        return 0, 0, image.shape[1], image.shape[0]

    largest_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(largest_contour)

    return x, y, w, h

def perf_augmentation(image_path, angle, zoom, shear_x, shear_y, img_size):
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    image_on_canvas = fix_canvas(image, img_size)

    rotated_image = rotate_image(image_on_canvas, angle)
    zoomed_image = random_zoom(rotated_image, zoom)
    sheared_image = random_shear(zoomed_image, shear_x, shear_y)
    x0, y0, w, h = get_bbox(sheared_image)

    norm_x_center = (x0 + w / 2) / img_size[1]
    norm_y_center = (y0 + h / 2) / img_size[0]
    norm_width = w / img_size[1]
    norm_height = h / img_size[0]

    cropped_image = sheared_image[y0:y0+h, x0:x0+w]
    
    shadowed_image = random_shadows(cropped_image)
    final_image = random_noise(shadowed_image)

    return final_image, (norm_x_center, norm_y_center, norm_width, norm_height)

def gen_aug_params():
    random_angle = random.uniform(-45, 45)
    random_zoom = random.uniform(0.15, 0.25)
    random_shear_x = random.uniform(-0.25, 0.25)
    random_shear_y = random.uniform(-0.25, 0.25)
    return random_angle, random_zoom, random_shear_x, random_shear_y

def normalize_bbox(bbox, img_size):
    x, y, w, h = bbox
    img_width, img_height = img_size
    norm_x_center = (x + w / 2) / img_width
    norm_y_center = (y + h / 2) / img_height
    norm_width = w / img_width
    norm_height = h / img_height
    return norm_x_center, norm_y_center, norm_width, norm_height

def gen_card_images(num_cards, img_size):
    card_images = []
    card_masks = []
    card_labels = []
    card_polygons = []
    aug_params = gen_aug_params()

    for _ in range(num_cards):
        card_path = random.choice(os.listdir('cards'))
        card_label = os.path.splitext(card_path)[0]
        card_image_path = f'cards/{card_path}'

        augmented_card, bbox = perf_augmentation(card_image_path, *aug_params, img_size)
        card_mask = np.zeros(augmented_card.shape[:2], dtype=np.uint8)
        card_mask[augmented_card[:, :, 3] > 0] = 255
        polygon_points = map_poly(card_mask)

        card_images.append(augmented_card)
        card_masks.append(bbox)
        card_labels.append(label_to_id.get(card_label, -1))
        card_polygons.append(polygon_points)

    return card_images, card_masks, card_labels, card_polygons

def card_overlay(card_images, card_bboxes, card_polygons, background, card_labels):
    annotations = []
    background_height, background_width = background.shape[:2]

    if background.shape[2] == 3:
        background = cv2.cvtColor(background, cv2.COLOR_BGR2BGRA)

    start_x = random.randint(30, 150)
    start_y = random.randint(30, 150)
    rotation_angle = random.randint(-10, 10)

    for idx, (card_image, bbox, polygon, label) in enumerate(zip(card_images, card_bboxes, card_polygons, card_labels)):
        overlap_x = random.randint(25, 30)
        overlap_y = random.randint(15, 20)
        
        x_offset = start_x + idx * overlap_x
        y_offset = start_y + idx * overlap_y

        card_center = (card_image.shape[1] // 2, card_image.shape[0] // 2)
        rotated_card_image = rotate_image(card_image, rotation_angle * idx)
        
        end_x = min(x_offset + rotated_card_image.shape[1], background_width)
        end_y = min(y_offset + rotated_card_image.shape[0], background_height)

        alpha_s = rotated_card_image[:, :, 3] / 255.0
        alpha_l = 1.0 - alpha_s

        for c in range(0, 3):
            background[y_offset:end_y, x_offset:end_x, c] = (alpha_s * rotated_card_image[:, :, c] +
                                                            alpha_l * background[y_offset:end_y, x_offset:end_x, c])
        transformed_polygon = transform_poly(polygon, x_offset, y_offset, rotation_angle * idx, card_center)

        annotations.append({
            "category_id": label,
            "bbox": bbox,
            "segmentation": transformed_polygon
        })

    return background, annotations

def normalize_poly(polygon, image_width, image_height):
    return [(x / image_width, y / image_height) for x, y in polygon]

def map_poly(mask):
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        return []

    largest_contour = max(contours, key=cv2.contourArea)

    epsilon = 0.01 * cv2.arcLength(largest_contour, True)
    approx = cv2.approxPolyDP(largest_contour, epsilon, True)
    return [(int(point[0][0]), int(point[0][1])) for point in approx]

def transform_poly(polygon, x_offset, y_offset, rotation_angle, card_center):
    transformed_polygon = []
    for x, y in polygon:
        x_rotated, y_rotated = rotate_point(x, y, rotation_angle, card_center[0], card_center[1])

        x_translated = x_rotated + x_offset
        y_translated = y_rotated + y_offset

        transformed_polygon.append((x_translated, y_translated))

    return transformed_polygon


def rotate_point(x, y, angle, cx, cy):
    angle = radians(angle)
    x_rotated = cos(angle) * (x - cx) - sin(angle) * (y - cy) + cx
    y_rotated = sin(angle) * (x - cx) + cos(angle) * (y - cy) + cy
    return x_rotated, y_rotated


def seg_annotations(base_name, annotations, labels_dir):
    os.makedirs(labels_dir, exist_ok=True)
    file_path = os.path.join(labels_dir, f'{base_name}.txt')

    with open(file_path, 'w') as file:
        for annotation in annotations:
            class_index = annotation['category_id']
            points = annotation['segmentation']
            line = f"{class_index} " + " ".join(f"{round(x.real, 6)} {round(y.real, 6)}" for x, y in points)
            file.write(line + "\n")

    print(f"Saved YOLO annotations to {file_path}")



def gen_dataset(num_images=10000, img_size=(512, 512)):
    dir = 'D:/yolo/data/images/val/'
    
    for i in range(num_images):
        base_name = f'image_{i:06d}'
        background = gen_background()
        resized_background = cv2.resize(background, img_size)
        #num_cards = random.randint(1, 5)
        num_cards = 1
        card_images, card_masks, card_labels, card_polygons = gen_card_images(num_cards, img_size)

        final_image, transformed_annotations = card_overlay(card_images, card_masks, card_polygons, resized_background, card_labels)

        for annotation in transformed_annotations:
            transformed_polygon = annotation['segmentation']
            normalized_polygon = normalize_poly(transformed_polygon, img_size[0], img_size[1])
            annotation['segmentation'] = normalized_polygon

        os.makedirs(dir, exist_ok=True)
        image_path = os.path.join(dir, f'{base_name}.png')
        cv2.imwrite(image_path, final_image)
        print(f"Saved {image_path}")

        seg_annotations(base_name, transformed_annotations, labels_dir='D:/yolo/data/labels/val/')

# %%
gen_dataset()
# Out:
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000000.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000000.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000001.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000001.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000002.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000002.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000003.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000003.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000004.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000004.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000005.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000005.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000006.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000006.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000007.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000007.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000008.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000008.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000009.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000009.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000010.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000010.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000011.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000011.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000012.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000012.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000013.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000013.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000014.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000014.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000015.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000015.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000016.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000016.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000017.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000017.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000018.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000018.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000019.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000019.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000020.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000020.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000021.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000021.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000022.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000022.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000023.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000023.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000024.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000024.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000025.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000025.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000026.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000026.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000027.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000027.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000028.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000028.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000029.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000029.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000030.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000030.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000031.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000031.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000032.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000032.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000033.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000033.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000034.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000034.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000035.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000035.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000036.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000036.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000037.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000037.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000038.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000038.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000039.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000039.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000040.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000040.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000041.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000041.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000042.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000042.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000043.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000043.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000044.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000044.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000045.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000045.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000046.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000046.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000047.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000047.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000048.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000048.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000049.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000049.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000050.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000050.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000051.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000051.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000052.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000052.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000053.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000053.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000054.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000054.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000055.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000055.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000056.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000056.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000057.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000057.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000058.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000058.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000059.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000059.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000060.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000060.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000061.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000061.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000062.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000062.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000063.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000063.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000064.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000064.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000065.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000065.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000066.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000066.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000067.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000067.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000068.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000068.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000069.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000069.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000070.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000070.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000071.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000071.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000072.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000072.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000073.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000073.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000074.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000074.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000075.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000075.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000076.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000076.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000077.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000077.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000078.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000078.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000079.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000079.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000080.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000080.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000081.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000081.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000082.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000082.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000083.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000083.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000084.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000084.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000085.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000085.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000086.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000086.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000087.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000087.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000088.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000088.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000089.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000089.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000090.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000090.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000091.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000091.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000092.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000092.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000093.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000093.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000094.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000094.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000095.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000095.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000096.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000096.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000097.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000097.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000098.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000098.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000099.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000099.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000100.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000100.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000101.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000101.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000102.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000102.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000103.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000103.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000104.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000104.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000105.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000105.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000106.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000106.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000107.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000107.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000108.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000108.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000109.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000109.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000110.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000110.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000111.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000111.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000112.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000112.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000113.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000113.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000114.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000114.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000115.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000115.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000116.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000116.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000117.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000117.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000118.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000118.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000119.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000119.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000120.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000120.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000121.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000121.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000122.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000122.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000123.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000123.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000124.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000124.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000125.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000125.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000126.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000126.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000127.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000127.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000128.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000128.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000129.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000129.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000130.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000130.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000131.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000131.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000132.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000132.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000133.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000133.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000134.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000134.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000135.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000135.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000136.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000136.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000137.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000137.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000138.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000138.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000139.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000139.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000140.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000140.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000141.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000141.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000142.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000142.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000143.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000143.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000144.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000144.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000145.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000145.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000146.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000146.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000147.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000147.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000148.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000148.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000149.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000149.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000150.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000150.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000151.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000151.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000152.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000152.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000153.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000153.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000154.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000154.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000155.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000155.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000156.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000156.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000157.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000157.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000158.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000158.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000159.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000159.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000160.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000160.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000161.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000161.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000162.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000162.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000163.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000163.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000164.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000164.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000165.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000165.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000166.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000166.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000167.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000167.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000168.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000168.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000169.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000169.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000170.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000170.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000171.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000171.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000172.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000172.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000173.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000173.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000174.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000174.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000175.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000175.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000176.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000176.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000177.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000177.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000178.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000178.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000179.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000179.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000180.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000180.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000181.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000181.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000182.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000182.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000183.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000183.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000184.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000184.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000185.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000185.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000186.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000186.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000187.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000187.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000188.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000188.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000189.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000189.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000190.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000190.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000191.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000191.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000192.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000192.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000193.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000193.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000194.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000194.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000195.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000195.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000196.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000196.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000197.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000197.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000198.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000198.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_000199.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000199.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000200.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000200.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000201.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000201.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000202.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000202.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000203.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000203.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000204.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000204.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000205.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000205.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000206.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000206.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000207.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000207.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000208.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000208.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000209.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000209.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000210.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000210.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000211.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000211.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000212.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000212.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000213.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000213.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000214.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000214.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000215.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000215.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000216.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000216.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000217.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000217.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000218.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000218.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000219.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000219.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000220.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000220.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000221.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000221.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000222.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000222.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000223.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000223.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000224.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000224.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000225.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000225.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000226.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000226.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000227.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000227.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000228.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000228.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000229.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000229.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000230.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000230.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000231.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000231.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000232.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000232.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000233.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000233.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000234.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000234.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000235.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000235.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000236.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000236.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000237.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000237.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000238.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000238.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000239.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000239.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000240.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000240.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000241.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000241.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000242.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000242.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000243.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000243.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000244.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000244.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000245.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000245.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000246.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000246.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000247.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000247.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000248.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000248.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000249.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000249.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000250.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000250.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000251.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000251.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000252.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000252.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000253.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000253.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000254.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000254.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000255.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000255.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000256.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000256.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000257.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000257.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000258.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000258.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000259.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000259.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000260.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000260.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000261.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000261.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000262.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000262.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000263.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000263.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000264.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000264.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000265.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000265.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000266.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000266.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000267.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000267.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000268.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000268.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000269.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000269.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000270.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000270.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000271.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000271.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000272.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000272.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000273.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000273.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000274.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000274.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000275.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000275.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000276.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000276.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000277.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000277.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000278.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000278.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_000279.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000279.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000280.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000280.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000281.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000281.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000282.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000282.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000283.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000283.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000284.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000284.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000285.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000285.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000286.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000286.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_000287.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000287.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000288.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000288.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000289.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000289.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_000290.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000290.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_000291.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000291.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_000292.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000292.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000293.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000293.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000294.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000294.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000295.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000295.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000296.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000296.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_000297.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000297.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000298.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000298.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000299.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000299.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_000300.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000300.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000301.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000301.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000302.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000302.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_000303.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000303.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_000304.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000304.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_000305.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000305.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000306.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000306.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_000307.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000307.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000308.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000308.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_000309.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000309.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000310.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000310.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000311.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000311.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000312.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000312.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_000313.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000313.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_000314.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000314.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_000315.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000315.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000316.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000316.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000317.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000317.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000318.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_000318.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_000319.png
# ...
# Saved D:/yolo/data/images/val/image_004227.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004227.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004228.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004228.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_004229.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004229.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004230.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004230.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_004231.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004231.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_004232.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004232.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004233.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004233.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004234.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004234.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004235.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004235.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_004236.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004236.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004237.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004237.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_004238.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004238.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004239.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004239.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_004240.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004240.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004241.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004241.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_004242.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004242.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004243.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004243.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_004244.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004244.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004245.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004245.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004246.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004246.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004247.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004247.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004248.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004248.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004249.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004249.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_004250.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004250.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_004251.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004251.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004252.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004252.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004253.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004253.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004254.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004254.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_004255.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004255.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_004256.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004256.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004257.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004257.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_004258.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004258.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_004259.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004259.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004260.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004260.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_004261.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004261.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_004262.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004262.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004263.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004263.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004264.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004264.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_004265.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004265.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_004266.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004266.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004267.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004267.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004268.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004268.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004269.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004269.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_004270.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004270.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004271.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004271.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_004272.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004272.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_004273.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004273.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004274.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004274.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_004275.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004275.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004276.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004276.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_004277.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004277.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_004278.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004278.txt
# pexels-jj-jordan-9304725.jpg
# Saved D:/yolo/data/images/val/image_004279.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004279.txt
# leo-yxMx0TEpbwY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004280.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004280.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004281.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004281.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004282.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004282.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004283.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004283.txt
# pexels-dhally-romy-12656497.jpg
# Saved D:/yolo/data/images/val/image_004284.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004284.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004285.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004285.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004286.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004286.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_004287.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004287.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004288.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004288.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004289.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004289.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004290.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004290.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_004291.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004291.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_004292.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004292.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004293.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004293.txt
# pexels-kevin-bidwell-3863792.jpg
# Saved D:/yolo/data/images/val/image_004294.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004294.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004295.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004295.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_004296.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004296.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004297.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004297.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004298.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004298.txt
# pexels-alena-koval-886521.jpg
# Saved D:/yolo/data/images/val/image_004299.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004299.txt
# pexels-erik-mclean-6654173.jpg
# Saved D:/yolo/data/images/val/image_004300.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004300.txt
# jess-bailey-q10VITrVYUM-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004301.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004301.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004302.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004302.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004303.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004303.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004304.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004304.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004305.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004305.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_004306.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004306.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_004307.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004307.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_004308.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004308.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004309.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004309.txt
# shamrocks-background-green-color_23-2147505834.jpg
# Saved D:/yolo/data/images/val/image_004310.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004310.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004311.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004311.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004312.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004312.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_004313.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004313.txt
# pexels-karolina-grabowska-4022082.jpg
# Saved D:/yolo/data/images/val/image_004314.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004314.txt
# charlie-lVH3nplcE50-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004315.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004315.txt
# pexels-monstera-production-7794266.jpg
# Saved D:/yolo/data/images/val/image_004316.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004316.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004317.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004317.txt
# pexels-karolina-grabowska-4226882.jpg
# Saved D:/yolo/data/images/val/image_004318.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004318.txt
# pexels-dids-3794359.jpg
# Saved D:/yolo/data/images/val/image_004319.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004319.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_004320.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004320.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004321.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004321.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004322.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004322.txt
# pexels-roman-odintsov-4925691.jpg
# Saved D:/yolo/data/images/val/image_004323.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004323.txt
# kevin-oetiker-M1UCyTnepCY-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004324.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004324.txt
# pexels-jess-bailey-designs-743986.jpg
# Saved D:/yolo/data/images/val/image_004325.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004325.txt
# gayatri-malhotra-tRvWnKbVZrk-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004326.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004326.txt
# pexels-high-rollick-studio-16707454.jpg
# Saved D:/yolo/data/images/val/image_004327.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004327.txt
# pexels-brett-sayles-5326743.jpg
# Saved D:/yolo/data/images/val/image_004328.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004328.txt
# pexels-karolina-grabowska-4033321.jpg
# Saved D:/yolo/data/images/val/image_004329.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004329.txt
# alina-rubo-RHa2IWIHH-w-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004330.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004330.txt
# pexels-markus-winkler-18524138.jpg
# Saved D:/yolo/data/images/val/image_004331.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004331.txt
# christin-hume-hBuwVLcYTnA-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004332.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004332.txt
# joakim-nadell-cFs_R1c71CI-unsplash.jpg
# Saved D:/yolo/data/images/val/image_004333.png
# Saved YOLO annotations to D:/yolo/data/labels/val/image_004333.txt
# pexels-erik-mclean-6654173.jpg
